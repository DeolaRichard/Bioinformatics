# %% [markdown]
# <a href="https://colab.research.google.com/github/DeolaRichard/Bioinformatics/blob/master/Copy_of_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 932.6 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.26.16)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                                 Murine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# 6                                   SARS coronavirus
# 7  Middle East respiratory syndrome-related coron...
# 8                                   SARS coronavirus
# 9    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   14.0
# 2                                 Feline coronavirus   14.0
# 3                                 Murine coronavirus   14.0
# 4                             Human coronavirus 229E   12.0
# 5                             Human coronavirus OC43   12.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False    CHEMBL5209664
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM   694005
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %%
selected_target = targets.target_chembl_id[7]
selected_target
# Out:
# 'CHEMBL4296578'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     18893658                  []
# 1         None             None     18893659                  []
# 2         None             None     18893660                  []
# 3         None             None     18893661                  []
# 4         None             None     18893662                  []
# ..         ...              ...          ...                 ...
# 95        None             None     24789289                  []
# 96        None             None     24789290                  []
# 97        None             None     24789291                  []
# 98        None             None     24789292                  []
# 99        None             None     24819146                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 1    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 2    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 3    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 4    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# ..             ...                                                ...
# 95   CHEMBL5132016                Antiviral activity against MERS-CoV
# 96   CHEMBL5132016                Antiviral activity against MERS-CoV
# 97   CHEMBL5132016                Antiviral activity against MERS-CoV
# 98   CHEMBL5132016                Antiviral activity against MERS-CoV
# 99   CHEMBL5139924  Antiviral activity against MERS-CoV assessed a...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           F                    None                   None  BAO_0000190
# 1           F                    None                   None  BAO_0000190
# 2           F                    None                   None  BAO_0000190
# 3           F                    None                   None  BAO_0000190
# 4           F                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 95          F                    None                   None  BAO_0000190
# 96          F                    None                   None  BAO_0000190
# 97          F                    None                   None  BAO_0000190
# 98          F                    None                   None  BAO_0000190
# 99          F                    None                   None  BAO_0000190
#
#     ...                                    target_organism  \
# 0   ...  Middle East respiratory syndrome-related coron...
# 1   ...  Middle East respiratory syndrome-related coron...
# 2   ...  Middle East respiratory syndrome-related coron...
# 3   ...  Middle East respiratory syndrome-related coron...
# 4   ...  Middle East respiratory syndrome-related coron...
# ..  ...                                                ...
# 95  ...  Middle East respiratory syndrome-related coron...
# 96  ...  Middle East respiratory syndrome-related coron...
# 97  ...  Middle East respiratory syndrome-related coron...
# 98  ...  Middle East respiratory syndrome-related coron...
# 99  ...  Middle East respiratory syndrome-related coron...
#
#                                      target_pref_name target_tax_id  \
# 0   Middle East respiratory syndrome-related coron...       1335626
# 1   Middle East respiratory syndrome-related coron...       1335626
# 2   Middle East respiratory syndrome-related coron...       1335626
# 3   Middle East respiratory syndrome-related coron...       1335626
# 4   Middle East respiratory syndrome-related coron...       1335626
# ..                                                ...           ...
# 95  Middle East respiratory syndrome-related coron...       1335626
# 96  Middle East respiratory syndrome-related coron...       1335626
# 97  Middle East respiratory syndrome-related coron...       1335626
# 98  Middle East respiratory syndrome-related coron...       1335626
# 99  Middle East respiratory syndrome-related coron...       1335626
#
#    text_value  toid  type units    uo_units upper_value               value
# 0        None  None  IC50    uM  UO_0000065        None                0.77
# 1        None  None  IC50    uM  UO_0000065        None                25.0
# 2        None  None  IC50    uM  UO_0000065        None                25.0
# 3        None  None  IC50    uM  UO_0000065        None                25.0
# 4        None  None  IC50    uM  UO_0000065        None                0.15
# ..        ...   ...   ...   ...         ...         ...                 ...
# 95       None  None  IC50    uM  UO_0000065        None               0.807
# 96       None  None  IC50    uM  UO_0000065        None               0.873
# 97       None  None  IC50    uM  UO_0000065        None                4.63
# 98       None  None  IC50    uM  UO_0000065        None  0.9129999999999999
# 99       None  None  IC50    nM  UO_0000065        None                21.0
#
# [100 rows x 46 columns]

# %%
df.to_csv('bioactivity_data.csv', index = False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data_csv
# Out:
# head: cannot open 'bioactivity_data_csv' for reading: No such file or directory

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,18893658,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C(F)(F)F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4471536,,CHEMBL4471536,6.11,0,http://www.openphacts.org/units/Nanomolar,3152357,=,1,1,=,,IC50,nM,,770.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.77
# ,,18893659,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C(C)C)cccc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4472908,,CHEMBL4472908,,0,http://www.openphacts.org/units/Nanomolar,3152358,>,1,1,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,,18893660,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C)cc(C)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4580358,,CHEMBL4580358,,0,http://www.openphacts.org/units/Nanomolar,3152359,>,1,1,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,,18893661,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(C)Nc1[nH]c2c(C(F)(F)F)cc(Cl)cc2c(=O)c1C(=O)c1ccccc1,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4531009,,CHEMBL4531009,,0,http://www.openphacts.org/units/Nanomolar,3152360,>,1,1,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,,18893662,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(C(F)(F)F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4554138,,CHEMBL4554138,6.82,0,http://www.openphacts.org/units/Nanomolar,3152361,=,1,1,=,,IC50,nM,,150.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.15
# ,,18893663,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4530008,,CHEMBL4530008,6.01,0,http://www.openphacts.org/units/Nanomolar,3152356,=,1,1,=,,IC50,nM,,980.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.98
# ,,18893664,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c([N+](=O)[O-])cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4573119,,CHEMBL4573119,5.94,0,http://www.openphacts.org/units/Nanomolar,3152362,=,1,1,=,,IC50,nM,,1160.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,1.16
# ,,18893665,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(F)cc(F)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4554248,,CHEMBL4554248,5.97,0,http://www.openphacts.org/units/Nanomolar,3152363,=,1,1,=,,IC50,nM,,1060.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,1.06
# ,,18893666,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(Cl)cc(Cl)c(Cl)c2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4565616,,CHEMBL4565616,6.54,0,http://www.openphacts.org/units/Nanomolar,3152364,=,1,1,=,,IC50,nM,,290.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.29

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     18893658                  []
# 1         None             None     18893659                  []
# 2         None             None     18893660                  []
# 3         None             None     18893661                  []
# 4         None             None     18893662                  []
# ..         ...              ...          ...                 ...
# 95        None             None     24789289                  []
# 96        None             None     24789290                  []
# 97        None             None     24789291                  []
# 98        None             None     24789292                  []
# 99        None             None     24819146                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 1    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 2    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 3    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# 4    CHEMBL4315144  Antiviral activity against MERS-CoV KOR/KNIH/0...
# ..             ...                                                ...
# 95   CHEMBL5132016                Antiviral activity against MERS-CoV
# 96   CHEMBL5132016                Antiviral activity against MERS-CoV
# 97   CHEMBL5132016                Antiviral activity against MERS-CoV
# 98   CHEMBL5132016                Antiviral activity against MERS-CoV
# 99   CHEMBL5139924  Antiviral activity against MERS-CoV assessed a...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           F                    None                   None  BAO_0000190
# 1           F                    None                   None  BAO_0000190
# 2           F                    None                   None  BAO_0000190
# 3           F                    None                   None  BAO_0000190
# 4           F                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 95          F                    None                   None  BAO_0000190
# 96          F                    None                   None  BAO_0000190
# 97          F                    None                   None  BAO_0000190
# 98          F                    None                   None  BAO_0000190
# 99          F                    None                   None  BAO_0000190
#
#     ...                                    target_organism  \
# 0   ...  Middle East respiratory syndrome-related coron...
# 1   ...  Middle East respiratory syndrome-related coron...
# 2   ...  Middle East respiratory syndrome-related coron...
# 3   ...  Middle East respiratory syndrome-related coron...
# 4   ...  Middle East respiratory syndrome-related coron...
# ..  ...                                                ...
# 95  ...  Middle East respiratory syndrome-related coron...
# 96  ...  Middle East respiratory syndrome-related coron...
# 97  ...  Middle East respiratory syndrome-related coron...
# 98  ...  Middle East respiratory syndrome-related coron...
# 99  ...  Middle East respiratory syndrome-related coron...
#
#                                      target_pref_name target_tax_id  \
# 0   Middle East respiratory syndrome-related coron...       1335626
# 1   Middle East respiratory syndrome-related coron...       1335626
# 2   Middle East respiratory syndrome-related coron...       1335626
# 3   Middle East respiratory syndrome-related coron...       1335626
# 4   Middle East respiratory syndrome-related coron...       1335626
# ..                                                ...           ...
# 95  Middle East respiratory syndrome-related coron...       1335626
# 96  Middle East respiratory syndrome-related coron...       1335626
# 97  Middle East respiratory syndrome-related coron...       1335626
# 98  Middle East respiratory syndrome-related coron...       1335626
# 99  Middle East respiratory syndrome-related coron...       1335626
#
#    text_value  toid  type units    uo_units upper_value               value
# 0        None  None  IC50    uM  UO_0000065        None                0.77
# 1        None  None  IC50    uM  UO_0000065        None                25.0
# 2        None  None  IC50    uM  UO_0000065        None                25.0
# 3        None  None  IC50    uM  UO_0000065        None                25.0
# 4        None  None  IC50    uM  UO_0000065        None                0.15
# ..        ...   ...   ...   ...         ...         ...                 ...
# 95       None  None  IC50    uM  UO_0000065        None               0.807
# 96       None  None  IC50    uM  UO_0000065        None               0.873
# 97       None  None  IC50    uM  UO_0000065        None                4.63
# 98       None  None  IC50    uM  UO_0000065        None  0.9129999999999999
# 99       None  None  IC50    nM  UO_0000065        None                21.0
#
# [100 rows x 46 columns]

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("Inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("Active")
  else:
    bioactivity_class.append("Intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, standard_value, bioactivity_class))
df3 = pd.DataFrame( data_tuples, columns = ['molecule_chembl_id', 'canonical_smiles', 'standard_value', 'bioactivity_class'])

# %%
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL4471536    CC(=O)c1c(NC(C)C)[nH]c2c(C(F)(F)F)cc(Cl)cc2c1=O
# 1       CHEMBL4472908           CC(=O)c1c(NC(C)C)[nH]c2c(C(C)C)cccc2c1=O
# 2       CHEMBL4580358            CC(=O)c1c(NC(C)C)[nH]c2c(C)cc(C)cc2c1=O
# 3       CHEMBL4531009  CC(C)Nc1[nH]c2c(C(F)(F)F)cc(Cl)cc2c(=O)c1C(=O)...
# 4       CHEMBL4554138  CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(C(F)(F)F)cc(Cl...
# ..                ...                                                ...
# 95      CHEMBL3301622  CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 96      CHEMBL2364626  CC(C)(C)Cn1c(N)nc2ccc(-c3[nH]c(C(C)(C)C)nc3-c3...
# 97       CHEMBL472620       Cn1nc(C(C)(C)C)cc1NC(=O)Nc1ccc(Oc2ccncc2)cc1
# 98      CHEMBL1088750  CC(C)Cn1ncc2cc(Oc3ccc(F)cc3F)c(C(=O)NCCN(C)C)cc21
# 99        CHEMBL55400                           Nc1ccc2cc3ccc(N)cc3nc2c1
#
#    standard_value bioactivity_class
# 0           770.0            Active
# 1         25000.0          Inactive
# 2         25000.0          Inactive
# 3         25000.0          Inactive
# 4           150.0            Active
# ..            ...               ...
# 95          807.0            Active
# 96          873.0            Active
# 97         4630.0      Intermediate
# 98          913.0            Active
# 99           21.0            Active
#
# [100 rows x 4 columns]

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index = False)

# %%
! ls -l
# Out:
# total 96
# -rw-r--r-- 1 root root 76498 Aug 10 03:06 bioactivity_data.csv
# -rw-r--r-- 1 root root 11826 Aug 10 05:09 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Aug 10 03:07 gdrive
# drwxr-xr-x 1 root root  4096 Aug  8 13:38 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
